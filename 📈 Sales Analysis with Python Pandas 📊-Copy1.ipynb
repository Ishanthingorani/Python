# %% [markdown]
# # SALES DATA ANALYSIS USING PANDAS

# %%
import pandas as pd

# %%
df = pd.read_csv("25. sales_data_final.csv")

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
# checking for missing values

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
# Product Details

# %%
df.sub_category
# Out:
# 0            Storage
# 1           Supplies
# 2            Storage
# 3              Paper
# 4        Furnishings
#             ...
# 51285        Binders
# 51286        Binders
# 51287         Labels
# 51288         Labels
# 51289      Fasteners
# Name: sub_category, Length: 51290, dtype: object

# %%
df.category
# Out:
# 0        Office Supplies
# 1        Office Supplies
# 2        Office Supplies
# 3        Office Supplies
# 4              Furniture
#               ...
# 51285    Office Supplies
# 51286    Office Supplies
# 51287    Office Supplies
# 51288    Office Supplies
# 51289    Office Supplies
# Name: category, Length: 51290, dtype: object

# %%
df.profit
# Out:
# 0        106.1400
# 1         36.0360
# 2         29.6400
# 3        -26.0550
# 4         37.7700
#            ...
# 51285      4.5188
# 51286      0.4200
# 51287     12.3600
# 51288      0.5600
# 51289     -0.6048
# Name: profit, Length: 51290, dtype: float64

# %%
df["Cost_to_company"] = df["discount"] + df["shipping_cost"]

# %%
df[["discount", "shipping_cost", "Cost_to_company","profit"]]
# Out:
#        discount  shipping_cost  Cost_to_company    profit
# 0           0.0          35.46            35.46  106.1400
# 1           0.1           9.72             9.82   36.0360
# 2           0.0           8.17             8.17   29.6400
# 3           0.5           4.82             5.32  -26.0550
# 4           0.1           4.70             4.80   37.7700
# ...         ...            ...              ...       ...
# 51285       0.2           0.89             1.09    4.5188
# 51286       0.0           0.49             0.49    0.4200
# 51287       0.0           0.35             0.35   12.3600
# 51288       0.0           0.20             0.20    0.5600
# 51289       0.2           0.17             0.37   -0.6048
#
# [51290 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
#Identifying all unique values 
df.describe(include="all").T
# Out:
#                   count unique              top   freq         mean  \
# order_id          51290  25035   CA-2014-100111     14          NaN
# order_date        51290   1430        6/18/2014    135          NaN
# ship_date         51290   1464       11/22/2014    130          NaN
# ship_mode         51290      4   Standard Class  30775          NaN
# customer_name     51290    795  Muhammed Yedwab    108          NaN
# segment           51290      3         Consumer  26518          NaN
# state             51290   1094       California   2001          NaN
# country           51290    147    United States   9994          NaN
# market            51290      7             APAC  11002          NaN
# region            51290     13          Central  11117          NaN
# product_id        51290  10292  OFF-AR-10003651     35          NaN
# category          51290      3  Office Supplies  31273          NaN
# sub_category      51290     17          Binders   6152          NaN
# ...

# %% [markdown]
# # LOCand ILOC

# %%
df.loc[[2,5,6,7,8,9]]
# Out:
#         order_id order_date ship_date       ship_mode     customer_name  \
# 2   HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 5  IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6   CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7  IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8  ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9   IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
#
#      segment            state      country  market   region  ...  \
# 2   Consumer         Budapest      Hungary    EMEA     EMEA  ...
# 5   Consumer  New South Wales    Australia    APAC  Oceania  ...
# 6   Consumer          Ontario       Canada  Canada   Canada  ...
# 7  Corporate  New South Wales    Australia    APAC  Oceania  ...
# 8   Consumer         Auckland  New Zealand    APAC  Oceania  ...
# 9  Corporate           Ninawa         Iraq    EMEA     EMEA  ...
#
# ...

# %%
df.iloc[2:4, 5:8]
# Out:
#        segment      state  country
# 2     Consumer   Budapest  Hungary
# 3  Home Office  Stockholm   Sweden

# %%
# MAXIMUM DISCOUNT AND PROFIT IN TOTAL DATA FRAME

# %%
df.groupby("discount")["profit"].max()
# Out:
# discount
# 0.000    8399.97600
# 0.002     872.82816
# 0.070    1554.43200
# 0.100    2316.51000
# 0.150    1517.71200
# 0.170     946.63380
# 0.200    3919.98880
# 0.202     317.78720
# 0.250     822.66000
# 0.270     368.25600
# 0.300     726.82500
# 0.320      -6.01960
# 0.350     515.75250
# 0.370     139.64760
# 0.400    1119.99680
# 0.402      61.71600
# 0.450      18.03750
# 0.470      35.81760
# 0.500       0.00000
# 0.550     -70.39950
# 0.570     -72.60720
# 0.600      -0.70200
# 0.602     -25.92000
# 0.650     -74.83800
# 0.700      -0.59640
# 0.800      -0.94520
# 0.850   -1144.11600
# Name: profit, dtype: float64

# %%
df.groupby("discount")["profit"].min()
# Out:
# discount
# 0.000       0.00000
# 0.002      -2.13220
# 0.070    -147.60480
# 0.100    -445.44000
# 0.150    -597.68100
# 0.170    -429.39450
# 0.200   -1049.34060
# 0.202    -216.04200
# 0.250    -483.30000
# 0.270    -329.80950
# 0.300    -953.44200
# 0.320    -437.54040
# 0.350   -1128.43500
# 0.370    -813.61440
# 0.400   -1862.31240
# 0.402    -601.74176
# 0.450    -598.68750
# 0.470    -916.04430
# 0.500   -3839.99040
# 0.550    -976.50000
# 0.570   -1294.35030
# 0.600   -4088.37600
# 0.602    -916.71776
# 0.650   -1303.05600
# 0.700   -6599.97800
# 0.800   -3701.89280
# 0.850   -1924.54200
# Name: profit, dtype: float64

# %%
df.groupby("discount")["profit"].mean()
# Out:
# discount
# 0.000      61.039514
# 0.002     125.762649
# 0.070     140.990022
# 0.100      64.071216
# 0.150      50.602409
# 0.170      38.317107
# 0.200      23.552594
# 0.202     -14.518847
# 0.250       4.043371
# 0.270      -4.317213
# 0.300     -57.899557
# 0.320     -88.560656
# 0.350    -116.144693
# 0.370     -78.462191
# 0.400     -45.246603
# 0.402    -109.908138
# 0.450     -41.610973
# 0.470     -42.982420
# 0.500     -97.140158
# 0.550    -315.067200
# 0.570    -526.129000
# 0.600     -81.732147
# 0.602    -213.279085
# 0.650    -365.997971
# 0.700    -104.339576
# 0.800    -122.203244
# 0.850   -1534.329000
# Name: profit, dtype: float64

# %%
df.plot()
# Out:
# <Axes: >

# %%
newdf=df[["discount", "shipping_cost", "Cost_to_company","profit"]].sample(100)

# %%
newdf.plot(figsize=(40,20), title = "IRIS Dataset",  kind="bar")
# Out:
# <Axes: title={'center': 'IRIS Dataset'}>

# %%
newdf.diff().hist(color = 'r', alpha = 0.5, figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'discount'}>,
#         <Axes: title={'center': 'shipping_cost'}>],
#        [<Axes: title={'center': 'Cost_to_company'}>,
#         <Axes: title={'center': 'profit'}>]], dtype=object)

# %%
Finaldf=df[["discount", "shipping_cost", "Cost_to_company","profit"]]

# %%
Finaldf.diff().hist(color = 'r', alpha = 0.5, figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'discount'}>,
#         <Axes: title={'center': 'shipping_cost'}>],
#        [<Axes: title={'center': 'Cost_to_company'}>,
#         <Axes: title={'center': 'profit'}>]], dtype=object)

# %% [markdown]
# 📊 Taking it Further with Power BI:
# While this Python project using Pandas provided valuable insights, there's always room to elevate the analysis to the next level. Power BI, with its robust visualization and business intelligence capabilities, can offer a more interactive and dynamic exploration of the data.
#
# 🔍 Why Power BI?
#
# Interactive Dashboards: Create dynamic and interactive dashboards to explore sales data in real-time.
# Advanced Visualizations: Utilize a variety of advanced visualizations to uncover deeper patterns and trends.
# Data Modeling: Leverage Power BI's data modeling features for more complex relationships and calculations.
# 📈 Next-Level Analysis:
# Consider diving deeper into your sales data using Power BI's capabilities for:
#
# Time Series Analysis: Explore sales trends over time with interactive time series visualizations.
# Geospatial Analysis: Map sales data to uncover regional patterns and opportunities.
# Predictive Analytics: Implement predictive models within Power BI for forecasting future sales.
# 🚀 Seamless Integration:
# One of the strengths of Power BI is its seamless integration with various data sources. You can easily connect to your cleaned and processed data from Python, providing a comprehensive and unified view.
#
# 📢 Share Your Insights:
# Have you combined Python analysis with Power BI for a comprehensive approach? Share your experiences and tips on integrating these powerful tools. Let's continue the conversation on how the synergy of Python and Power BI can take data analysis to new heights!
